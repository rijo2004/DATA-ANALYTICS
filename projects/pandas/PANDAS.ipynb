# %%
#creating series
import pandas as pd
numbers=[10,20,30,40]
num_series= pd.Series(numbers)
num_series
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
#with custom index
marks = [12,23,45,78]
mark_series = pd.Series(marks,index=["rijo","arun","rahul","aflah"])
mark_series
# Out:
# rijo     12
# arun     23
# rahul    45
# aflah    78
# dtype: int64

# %%
#CREATING SERIES WITH DIC
student ={
    "name":"rijo",
    "age":21,
    "place":"pariyapuram"
}
stud_d = pd.Series(student)
stud_d
# Out:
# name            rijo
# age               21
# place    pariyapuram
# dtype: object

# %%
#accsessing with position
stud_d.iloc[0]
# Out:
# 'rijo'

# %%
#accsessing with label
stud_d.loc["name"]
# Out:
# 'rijo'

# %%
#printing all index values
stud_d.index
# Out:
# Index(['name', 'age', 'place'], dtype='object')

# %%
# data type
num_series.dtype
# Out:
# dtype('int64')

# %%
num_series.sum()
# Out:
# np.int64(100)

# %%
num_series.mean()
# Out:
# np.float64(25.0)

# %%
num_series.max()
# Out:
# 40

# %%
num_series.min()
# Out:
# 10

# %%
num_series.count()
# Out:
# np.int64(4)

# %%
# for printing the 1st 5 elements in the data
stud_d.head()
# Out:
# name            rijo
# age               21
# place    pariyapuram
# dtype: object

# %%
#for printing the element by the index
stud_d.head(1)
# Out:
# name    rijo
# dtype: object

# %%
# for printing the last 5 elements in the data
stud_d.tail()
# Out:
# name            rijo
# age               21
# place    pariyapuram
# dtype: object

# %%
#for printing the element using index
stud_d.tail(2)
# Out:
# age               21
# place    pariyapuram
# dtype: object

# %%
#filitering data
da =pd.Series([10,20,30,40,50,60])
da[da > 30]
# Out:
# 3    40
# 4    50
# 5    60
# dtype: int64

# %%
#updating data
da[1]=100
da
# Out:
# 0     10
# 1    100
# 2     30
# 3     40
# 4     50
# 5     60
# dtype: int64

# %%
da["new"]=20
da
# Out:
# 0       10
# 1      100
# 2       30
# 3       40
# 4       50
# 5       60
# new     20
# dtype: int64

# %%
da.drop("new")
# Out:
# 0     10
# 1    100
# 2     30
# 3     40
# 4     50
# 5     60
# dtype: int64

# %% [markdown]
# #DATA FRAME

# %%
import pandas as pd
stud ={
    "name":["aflah","vishnu","rijo","anadhu"],
     "age":[34,50,12,22],
     "course" :["UI/UX","phython","data analytics","C"]   
}
df = pd.DataFrame(stud)
df
# Out:
#      name  age          course
# 0   aflah   34           UI/UX
# 1  vishnu   50         phython
# 2    rijo   12  data analytics
# 3  anadhu   22               C

# %%
df.head()
# Out:
#      name  age          course
# 0   aflah   34           UI/UX
# 1  vishnu   50         phython
# 2    rijo   12  data analytics
# 3  anadhu   22               C

# %%
df.head(2)
# Out:
#      name  age   course
# 0   aflah   34    UI/UX
# 1  vishnu   50  phython

# %%
df.tail()
# Out:
#      name  age          course
# 0   aflah   34           UI/UX
# 1  vishnu   50         phython
# 2    rijo   12  data analytics
# 3  anadhu   22               C

# %%
df.tail(2)
# Out:
#      name  age          course
# 2    rijo   12  data analytics
# 3  anadhu   22               C

# %%
df.shape
# Out:
# (4, 3)

# %%
df.dtypes
# Out:
# name      object
# age        int64
# course    object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    4 non-null      object
#  1   age     4 non-null      int64
#  2   course  4 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 228.0+ bytes

# %%
df.columns
# Out:
# Index(['name', 'age', 'course'], dtype='object')

# %%
df.describe()
# Out:
#              age
# count   4.000000
# mean   29.500000
# std    16.360522
# min    12.000000
# 25%    19.500000
# 50%    28.000000
# 75%    38.000000
# max    50.000000

# %%
df[["name","course"]]
# Out:
#      name          course
# 0   aflah           UI/UX
# 1  vishnu         phython
# 2    rijo  data analytics
# 3  anadhu               C

# %%
df.loc[0]
# Out:
# name      aflah
# age          34
# course    UI/UX
# Name: 0, dtype: object

# %%
df.iloc[1]
# Out:
# name       vishnu
# age            50
# course    phython
# Name: 1, dtype: object

# %%
df["age"].sum()
# Out:
# np.int64(118)

# %%
df["age"].mean()
# Out:
# np.float64(29.5)

# %%
df["age"].max()
# Out:
# 50

# %%
df["age"].min()
# Out:
# 12

# %%
df["age"].count()
# Out:
# np.int64(4)

# %%
df[df["age"] > 45]
# Out:
#      name  age   course
# 1  vishnu   50  phython

# %%
df["palce"]=["pariyapuram","thrissur","kottayam","kannur"]
df
# Out:
#      name  age          course        palce
# 0   aflah   34           UI/UX  pariyapuram
# 1  vishnu   50         phython     thrissur
# 2    rijo   12  data analytics     kottayam
# 3  anadhu   22               C       kannur

# %%
df= df.drop("palce",axis = 1)

# %%
df
# Out:
#      name  age          course
# 0   aflah   34           UI/UX
# 1  vishnu   50         phython
# 2    rijo   12  data analytics
# 3  anadhu   22               C

# %%
df.to_csv("studentss.csv",index=False)
