# %%
def add(a,b):
    print(a+b)
add(10,20)
# Out:
# 30

# %%
def add(a,b):
    return a+b
result = add(10,20)
print(result)
print(result + 10)
print(result + result)
print(result * result)
# Out:
# 30
# 40
# 60
# 900

# %%
def add(a,b):
    return a+b
add(10,20)
# Out:
# 30
