# %%
list = ["apple","banana","kiwi","mango"]
print("total number of elements:",len(list))
# Out:
# total number of elements: 4

# %%
list = ["apple","banana","kiwi","mango"]
list.append("phython")
print(list)
# Out:
# ['apple', 'banana', 'kiwi', 'mango', 'phython']

# %%
list = ["apple","banana","kiwi","mango","grape","orange"]
list.insert(2,"strawberry")
print(list)
# Out:
# ['apple', 'banana', 'strawberry', 'kiwi', 'mango', 'grape', 'orange']

# %%
list = ["apple","banana","kiwi","mango","grape","orange"]
list[3]="watermelon"
print(list)
# Out:
# ['apple', 'banana', 'kiwi', 'watermelon', 'grape', 'orange']

# %%
list = ['apple', 'banana', 'strawberry', 'kiwi', 'mango', 'grape', 'orange']
list.remove("strawberry")
print(list)
# Out:
# ['apple', 'banana', 'kiwi', 'mango', 'grape', 'orange']

# %%
list = ['apple', 'banana', 'strawberry', 'kiwi', 'mango', 'grape', 'orange']
list.pop(1)
print(list)
# Out:
# ['apple', 'strawberry', 'kiwi', 'mango', 'grape', 'orange']

# %%
list = ['apple', 'banana', 'strawberry', 'kiwi', 'mango', 'grape', 'orange']
list.clear()
print(list)
# Out:
# []

# %%
list1 = ['apple', 'banana', 'strawberry']
list2 = ['kiwi', 'mango', 'grape', 'orange']
list1.extend(list2)
print(list1)
# Out:
# ['apple', 'banana', 'strawberry', 'kiwi', 'mango', 'grape', 'orange']
