# %%
x = str(input("enter the name :"))
print("hello", x)
# Out:
# enter the name : huj
# hello huj

# %%
x = str(input("enter the city :"))
print("i live in", x)
# Out:
# enter the city : perinthalmanna
# i live in perinthalmanna

# %%
a = "rijo"
print(a[0])
# Out:
# r

# %%
a = "rijo"
print(a[-1])
# Out:
# o

# %%
a = "printhalmanna"
print(a [::-1])
# Out:
# annamlahtnirp

# %%
a = "rijo"
print(a.upper())
# Out:
# RIJO

# %%
a = "RIJO"
print(a.lower())
# Out:
# rijo

# %%
a = "rijo"
print(a.replace("r","l"))
# Out:
# lijo

# %%
a = "perinthalmanna"
print(a.count("n"))
# Out:
# 3

# %%
# PHYTHONLIST

# %%
s = input("Enter sentence: ")

longest = ""

for i in s.split():
    if len(i) > len(longest):
        longest = i

print(longest)
