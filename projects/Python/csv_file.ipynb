# %%
import csv
with open("students.csv","w",newline="") as file:
  writer = csv.writer(file)
  writer.writerow(["NAME","AGE","PLACE","CLASS","BATCH"])
  writer.writerow(["rijo",21,"pariyapuram","data analytics","B2"])
  writer.writerow(["anjo",21,"pariyapuram","data analytics","B2"])
  writer.writerow(["aflah",21,"mankada","digital marketing","B1"])
  writer.writerow(["anandhu",21,"mankada","digital marketing","B1"])
  writer.writerow(["vishnu",21,"perinthalmanna","phython","B3"])
  writer.writerow(["sanju",21,"mankada","digital marketing","B1"])
  writer.writerow(["karthik",21,"perinthalmanna","UI/UX","B2"])
  writer.writerow(["rahul",21,"mankada","digital marketing","B1"])
  writer.writerow(["arun",21,"perinthalmanna","digital marketing","B3"])
  writer.writerow(["fadhil",21,"mankada","UI/UX","B1"])

# %%
#json file
import json

data = {"name":["rijo","sanju","anjo","joel"],"age":[21,34,55,67]}
with open("stud.json","w") as file:
    json.dump(data,file)
with open("stud.json","r") as file:
    print(json.load(file))
# Out:
# {'name': ['rijo', 'sanju', 'anjo', 'joel'], 'age': [21, 34, 55, 67]}
