# %%
x = int(input("enter the 1st number: "))
y = int(input("enter the 2nd number: "))
print("sum: ",x+y)
print("difference: ",x-y)
print("multiplication: ",x*y)
print("division: ",x/y)
print("exponation: ",x**y)
print("floor division: ",x//y)
# Out:
# enter the 1st number:  2
# enter the 2nd number:  1
# sum:  3
# difference:  1
# multiplication:  2
# division:  2.0
# exponation:  2
# floor division:  2

# %%
l = int(input("enter the length: "))
b = int(input("enter the breadth: "))
print("area of a rectangle:", l*b )
print("perimeter of a rectangle:", 2*(l+b ))
# Out:
# enter the length:  2
# enter the breadth:  3
# area of a rectangle: 6
# perimeter of a rectangle: 10

# %%
p = int(input("enter the principle amount: "))
r = int(input("enter the rate: "))
t = int(input("enter the time: "))
print ("simple interest = ", (a*b*c)/100)
# Out:
# enter the principle amount:  1
# enter the rate:  2
# enter the time:  3
# simple interest =  0.06

# %%
x = int(input("enter a number "))
print("square = ",x**2)
print(" cube = ",x**3)
# Out:
# enter a number  2
# square =  4
#  cube =  8

# %%
c = int(input("enter the temperature "))
f = ((9/5)*c)+32
print("faren",c)
# Out:
# enter the temperature  20
# faren 20

# %%
x = int(input("enter a number "))
print (x<=100 and x>=50)
# Out:
# enter a number  67
# True

# %%
x = int(input("enter a number "))
if (x<=100 and x>=50):
    print("yes,",x,"lies between 50 and 100")
else:
    print(x,"is not a number between 50 and 100")
# Out:
# enter a number  90
# yes, 90 lies between 50 and 100
