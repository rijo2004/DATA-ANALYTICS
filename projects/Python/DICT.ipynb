# %%
mydict = {
 "name":"rijo",
 "age": 20,
 "place":"pariyapuram" ,
 "course":"data analytics"   
}
print(mydict)
# Out:
# {'name': 'rijo', 'age': 20, 'place': 'pariyapuram', 'course': 'data analytics'}

# %%
list1 = [3,7,8,12,22]
list2 = [8,5,9,22,16,12]
x = set(list1)
y = set(list2)
z = y.intersection(x)
a = list(z)
print(a)
# Out:
# [8, 12, 22]

# %%
mydict = {
 "name":"rijo",
 "age": 20,
 "place":"pariyapuram" ,
 "course":"data analytics"   
}
print(mydict.values())
# Out:
# dict_values(['rijo', 20, 'pariyapuram', 'data analytics'])

# %%
mydict = {
 "name":"rijo",
 "age": 20,
 "place":"pariyapuram" ,
 "course":"data analytics"   
}
print(mydict.keys())
# Out:
# dict_keys(['name', 'age', 'place', 'course'])

# %%
mydict = {
 "name":"rijo",
 "age": 20,
 "place":"pariyapuram" ,
 "course":"data analytics"   
}
print(mydict.items())
# Out:
# dict_items([('name', 'rijo'), ('age', 20), ('place', 'pariyapuram'), ('course', 'data analytics')])

# %%
mydict = {
 "name":"rijo",
 "age": 20,
 "place":"pariyapuram" ,
 "course":"data analytics"   
}
for x in mydict.values():
    print(x)
# Out:
# rijo
# 20
# pariyapuram
# data analytics

# %%
mydict = {
 "name":"rijo",
 "age": 20,
 "place":"pariyapuram" ,
 "course":"data analytics"   
}
for x in mydict.keys():
    print(x)
# Out:
# name
# age
# place
# course

# %%
mydict = {
 "name":"rijo",
 "age": 20,
 "place":"pariyapuram" ,
 "course":"data analytics"   
}
mydict["insti"] = "softronics"
print(mydict)
# Out:
# {'name': 'rijo', 'age': 20, 'place': 'pariyapuram', 'course': 'data analytics', 'insti': 'softronics'}

# %%
mydict = {
 "name":"rijo",
 "age": 20,
 "place":"pariyapuram" ,
 "course":"data analytics"   
}
mydict["name"] = "sanju"
print(mydict)
# Out:
# {'name': 'sanju', 'age': 20, 'place': 'pariyapuram', 'course': 'data analytics'}

# %%
mydict = dict(name = "rijo",age = 20,place = "pariyapuram",course = "data analytics")
print(mydict)
# Out:
# {'name': 'rijo', 'age': 20, 'place': 'pariyapuram', 'course': 'data analytics'}

# %%
mydict = dict(name = "rijo",age = 20,place = "pariyapuram",course = "data analytics")
if "name" in mydict:
    print("yes 'rijo' in mydict")
# Out:
# yes 'rijo' in mydict
